# %% [markdown]
# # QTM 385
#
# ***
#
# ## Homework 4
#
# Student: [Xiuyi Qian 2474952]

# %% [markdown]
# In this homework, we will create an object called Student, that is useful for a professor to store information about a student.

# %% [markdown]
# ***
#
# ### Question 1
#
# Create a class Student, that has:
#
# 0. Id number (5-digits integer, starting with 1)
# 1. First Name (str)
# 2. Last Name (str)
# 3. Grades (list of floats)
# 4. Credits (list of integers)
# 5. Major (str)
#
# Provide a constructor for your class and create one fictitious student.

# %%
# Your answer here
class student:
    def __init__(self, _id, fname, lname, grades, credits, major):
        self.id = _id
        self.fname = fname
        self.lname = lname
        self.grades = grades
        self.credits = credits
        self.major = major
stu1 = student(10000,"topher",'chris',[90.0,85.0,70],[4,4,3],'maths')

# %% [markdown]
# ***
#
# ### Question 2
#
# Create a method to nicely display the student when we type `print`. It should display, for example:
#
# ```
# Student:
#     Id: 12345
#     Name: Mig, Umberto
#     Major: QSS
# ```
#
# Create a method that, when a variable storing a student is typed in the console, displays:
#
# ```
# Student(Mig, Umberto; 12345)
# ```
#
# Provide some testing with a fictitious result of your choice.

# %%
# Your answer here
class student:
    def __init__(self, _id, fname, lname, grades, credits, major):
        self.id = _id
        self.fname = fname
        self.lname = lname
        self.grades = grades
        self.credits = credits
        self.major = major
        
    def __str__(self):
        st_info = """
Student({lname}, {fname}; {_id})""".format(lname = self.lname,fname = self.fname, _id = self.id )
        return st_info
stu1 = student(10000,"topher",'chris',[90.0,85.0,70.0],[4,4,3],'maths') 
print(stu1)
# Out:
# Student(chris, topher; 10000)

# %% [markdown]
# ***
#
# ### Question 3
#
# Implement class methods for:
#
# 1. Check if the id number is valid (remember: 5 digits, starting with number one)
# 2. Check if the grades list has the same length as the credits list. The idea is that every grade corresponds to a course that gave the student a certain amount of credits.
# 3. Append grade and credit: given a grade, and credits attached to the grade, append both to each respective place.
#
# Test your function with a toy student of your choice.

# %%
# Your answer here
class student:
    def __init__(self, _id, fname, lname, grades, credits, major):
        self.id = _id
        self.fname = fname
        self.lname = lname
        self.grades = grades
        self.credits = credits
        self.major = major
        
    def __str__(self):
        st_info = """
Student({lname}, {fname}; {_id})""".format(lname = self.lname,fname = self.fname, _id = self.id )
        return st_info
    
    def checkid(self):
        return len(str(self.id)) == 5
    
    def checkgc(self):
        return len(self.grades) == len(self.credits)
    
    def upgrade_grade_credit(self,ngrade, ncredit):
        self.grades.append(ngrade)
        self.credits.append(ncredit)
        return self
    
stu1 = student(10000,"topher",'chris',[90.0,85.0,70.0],[4,4,3],'maths') 
print("check if id number is valid")
print(stu1.checkid())
print("check if the grades list has the same length as the credits list")
print(stu1.checkgc())
stu1 = stu1.upgrade_grade_credit(60.0,3)
print("Append grade and credit: given a grade, and credits attached to the grade")
print(stu1.grades)
print(stu1.credits)
# Out:
# check if id number is valid
# True
# check if the grades list has the same length as the credits list
# True
# Append grade and credit: given a grade, and credits attached to the grade
# [90.0, 85.0, 70.0, 60.0]
# [4, 4, 3, 3]

# %% [markdown]
# ***
#
# ### Question 4
#
# Create a module in the class Student that computes the unweighted average of the student's grades.

# %%
# Your answer here
class student:
    def __init__(self, _id, fname, lname, grades, credits, major):
        self.id = _id
        self.fname = fname
        self.lname = lname
        self.grades = grades
        self.credits = credits
        self.major = major
        
    def __str__(self):
        st_info = """
Student({lname}, {fname}; {_id})""".format(lname = self.lname,fname = self.fname, _id = self.id )
        return st_info
    
    def checkid(self):
        return len(str(self.id)) == 5
    
    def checkgc(self):
        return len(self.grades) == len(self.credits)
    
    def upgrade_grade_credit(self,ngrade, ncredit):
        self.grades.append(ngrade)
        self.credits.append(ncredit)
        return self
    
    def unw_avg_grades(self):
        return sum(self.grades)/len(self.grades)
        
stu1 = student(10000,"topher",'chris',[90.0,85.0,70.0],[4,4,3],'maths') 
print("grades")
print(stu1.grades)
print("unweighted average grades")
print(stu1.unw_avg_grades())
# Out:
# grades
# [90.0, 85.0, 70.0]
# unweighted average grades
# 81.66666666666667

# %% [markdown]
# ***
#
# ### Question 5
#
# Create a module in the class Student that computes the weighted average of the student's grades, weighted by the credits.

# %%
# Your answer here
# Your answer here
class student:
    def __init__(self, _id, fname, lname, grades, credits, major):
        self.id = _id
        self.fname = fname
        self.lname = lname
        self.grades = grades
        self.credits = credits
        self.major = major
        
    def __str__(self):
        st_info = """
Student({lname}, {fname}; {_id})""".format(lname = self.lname,fname = self.fname, _id = self.id )
        return st_info
    
    def checkid(self):
        return len(str(self.id)) == 5
    
    def checkgc(self):
        return len(self.grades) == len(self.credits)
    
    def upgrade_grade_credit(self,ngrade, ncredit):
        self.grades.append(ngrade)
        self.credits.append(ncredit)
        return self
    
    def w_avg_grades(self):
        tem = 0
        tcredits = sum(self.credits)
        for index in range(len(self.grades)):
            tem+= self.credits[index]/tcredits*self.grades[index]
        return tem
stu1 = student(10000,"topher",'chris',[90.0,85.0,70.0],[4,4,3],'maths') 
print("credits")
print(stu1.credits)
print("grades")
print(stu1.grades)
print("weighted average grade: " + str(stu1.w_avg_grades()))
# Out:
# credits
# [4, 4, 3]
# grades
# [90.0, 85.0, 70.0]
# weighted average grade: 82.72727272727273

# %% [markdown]
# **That's all, folks!**
